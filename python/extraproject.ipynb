# %%
import pandas as pd
import os

# %%
path_to_data = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-i-sedelkin/practice/data/extraproject/4_inn.xls'
path_to_ref = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-i-sedelkin/practice/data/extraproject/4_necessary_inn.txt'

# %%
data = pd.read_excel(path_to_database, index_col='#')
data.dtypes
# Out:
# Unnamed: 0                 int64
# name                      object
# reg_number                 int64
# address                   object
# head                      object
# head_job                  object
# head_inn                   int64
# phone                     object
# email                     object
# site                      object
# registration_date         object
# nalogoplatelschik_code    object
# oktmo_code                 int64
# okato_code                 int64
# registration_region       object
# okato_name                object
# field                     object
# capital,RUB                int64
# income,RUB                 int64
# dtype: object

# %%
ref = pd.read_fwf(path_to_ref, header=None, names=['inn'])
ref_inn = ref.inn

# %%
selected_inn = data.query('head_inn in @ref_inn')
selected_inn = selected_inn.drop(columns=['Unnamed: 0']).reset_index(drop=True)
selected_inn.head()
# Out:
#                      name     reg_number  \
# 0          Пермэнергосбыт  6417532956774
# 1  ЗАО «Кабанова Ковалев»  9343329412518
# 2                 Неофарм  3813743111150
# 3             Арконик СМЗ  7465966885549
# 4         Фармперспектива  6205521489390
#
#                                              address  \
# 0  ст. Слюдянка, пер. Брянский, д. 378 стр. 634, ...
# 1     с. Нарткала, ул. Верхняя, д. 68 стр. 1, 393309
# 2      г. Долинск, ш. Московское, д. 25 к. 5, 227970
# 3   п. Тобольск, ул. Лунная, д. 375 стр. 724, 119588
# 4  к. Горно-Алтайск, ул. Степана Разина, д. 646 с...
#
#                            head              head_job      head_inn  \
# 0     Емельян Феликсович Зайцев              Релайтер  175482780898
# 1  Геннадий Денисович Григорьев               Бондарь  120708914823
# 2       Юрий Архипович Богданов           Полицейский  663119569897
# 3       Аникей Артёмович Павлов  Оперативный работник  722903871682
# ...

# %%
selected_inn['income,RUB'].sum()
# Out:
# 6104522627393

# %%
path_to_result = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-i-sedelkin/practice/data/extraproject/selected_inn.csv'
selected_inn.to_csv(path_to_result)
